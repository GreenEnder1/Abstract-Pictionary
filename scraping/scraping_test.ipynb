# %% [markdown]
# Documentation for the library: https://pypi.org/project/duckduckgo-search/#4-images---image-search-by-duckduckgocom

# %%
from duckduckgo_search import DDGS
from duckduckgo_search import AsyncDDGS
import json

import urllib.request 
from PIL import Image

# %%
results = DDGS().text("python programming", max_results=5)
print(results)
# Out:
# [{'title': 'Welcome to Python.org', 'href': 'https://www.python.org/', 'body': 'Python is a versatile and easy-to-learn language that lets you work quickly and integrate systems more effectively. Learn Python basics, download the latest version, explore the documentation, join the community, and discover success stories and events.'}, {'title': 'Python For Beginners | Python.org', 'href': 'https://www.python.org/about/gettingstarted/', 'body': 'Learn how to get started with Python, a popular and easy-to-use programming language. Find out how to install, edit, and use Python, and explore its libraries, documentation, and community resources.'}, {'title': 'Python Tutorial - W3Schools', 'href': 'https://www.w3schools.com/python/', 'body': 'W3Schools offers a comprehensive and interactive Python tutorial with examples, exercises, quizzes, and references. You can learn Python for web development, file handling, database access, and more.'}, {'title': 'Python (programming language) - Wikipedia', 'href': 'https://en.wikipedia.org/wiki/Python_(programming_language)', 'body': 'Learn about Python, a high-level, general-purpose programming language with a focus on code readability and multiple paradigms. Find out its history, design, features, implementations, uses, and influences.'}, {'title': 'Python Tutorial | Learn Python Programming Language - GeeksforGeeks', 'href': 'https://www.geeksforgeeks.org/python-programming-language-tutorial/', 'body': 'A comprehensive guide to learn Python programming from basics to advanced level, covering syntax, data types, operators, loops, functions, OOPs, exceptions, and more. Includes examples, quizzes, and tips for beginners and professionals.'}]

# %%
def images(
    keywords: str,
    region: str = "wt-wt",
    safesearch: str = "moderate",
    timelimit: str | None = None,
    size: str | None = None,
    color: str | None = None,
    type_image: str | None = None,
    layout: str | None = None,
    license_image: str | None = None,
    max_results: int | None = None,
) -> list[dict[str, str]]:
    """DuckDuckGo images search. Query params: https://duckduckgo.com/params.
    
    Args:
        keywords: keywords for query.
        region: wt-wt, us-en, uk-en, ru-ru, etc. Defaults to "wt-wt".
        safesearch: on, moderate, off. Defaults to "moderate".
        timelimit: Day, Week, Month, Year. Defaults to None.
        size: Small, Medium, Large, Wallpaper. Defaults to None.
        color: color, Monochrome, Red, Orange, Yellow, Green, Blue,
            Purple, Pink, Brown, Black, Gray, Teal, White. Defaults to None.
        type_image: photo, clipart, gif, transparent, line.
            Defaults to None.
        layout: Square, Tall, Wide. Defaults to None.
        license_image: any (All Creative Commons), Public (PublicDomain),
            Share (Free to Share and Use), ShareCommercially (Free to Share and Use Commercially),
            Modify (Free to Modify, Share, and Use), ModifyCommercially (Free to Modify, Share, and
            Use Commercially). Defaults to None.
        max_results: max number of results. If None, returns results only from the first response. Defaults to None.
    
    Returns:
        List of dictionaries with images search results.
    """

# %%
results = DDGS().images(
    keywords="butterfly",
    region="wt-wt",
    safesearch="off",
    size=None,
    color="Monochrome",
    type_image=None,
    layout=None,
    license_image=None,
    max_results=100,
)

# async

found_images = []
results = await AsyncDDGS().aimages('butterfly', region='wt-wt', safesearch='off', max_results=20)
for result in results:
    found_images.append(result['image'])
    result = json.dumps(result, indent=4, sort_keys=True)
    print(result)
print(found_images)
# Out:
# {
#     "height": 2000,
#     "image": "http://upload.wikimedia.org/wikipedia/commons/a/ab/Monarch_Butterfly_Showy_Male_3000px.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse3.mm.bing.net/th?id=OIP.DFtDWy0uR7EIRkqvefasXAHaE8&pid=Api",
#     "title": "File:Monarch Butterfly Showy Male 3000px.jpg - Wikimedia Commons",
#     "url": "http://commons.wikimedia.org/wiki/file:monarch_butterfly_showy_male_3000px.jpg",
#     "width": 3000
# }
# {
#     "height": 1110,
#     "image": "https://cdn.britannica.com/76/151376-050-13586FE2/monarch-butterfly-flowers-bush.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse3.mm.bing.net/th?id=OIP.ktWnwh3zlTaAT6O8xKPdwwHaFI&pid=Api",
#     "title": "Monarch butterfly | Life Cycle, Caterpillar, Migration, Endangered ...",
#     "url": "https://www.britannica.com/animal/monarch-butterfly",
#     "width": 1600
# }
# {
#     "height": 2592,
#     "image": "http://upload.wikimedia.org/wikipedia/commons/7/7c/Butterfly_macro.JPG",
#     "source": "Bing",
#     "thumbnail": "https://tse2.mm.bing.net/th?id=OIP.bYImGKQeFz6VMt8Kt48E7QHaE9&pid=Api",
#     "title": "File:Butterfly macro.JPG - Wikimedia Commons",
#     "url": "http://commons.wikipedia.org/wiki/file:butterfly_macro.jpg",
#     "width": 3872
# }
# {
#     "height": 2000,
#     "image": "http://upload.wikimedia.org/wikipedia/commons/b/b5/Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_2800px.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse4.mm.bing.net/th?id=OIP.25fL_HBlC6ZoeBEtrUzQJgHaFS&pid=Api",
#     "title": "File:Monarch Butterfly Danaus plexippus on Echinacea purpurea 2800px ...",
#     "url": "http://commons.wikimedia.org/wiki/file:monarch_butterfly_danaus_plexippus_on_echinacea_purpurea_2800px.jpg",
#     "width": 2800
# }
# {
#     "height": 2232,
#     "image": "http://upload.wikimedia.org/wikipedia/commons/2/20/Monarch_Butterfly_resting_on_fennel,_at_the_Pismo_Butterfly_Grove,_California.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse2.mm.bing.net/th?id=OIP.zmqoRKiBfOYom1SN7QtfEgHaFk&pid=Api",
#     "title": "File:Monarch Butterfly resting on fennel, at the Pismo Butterfly Grove ...",
#     "url": "http://commons.wikimedia.org/wiki/File:Monarch_Butterfly_resting_on_fennel,_at_the_Pismo_Butterfly_Grove,_California.jpg",
#     "width": 2964
# }
# {
#     "height": 795,
#     "image": "http://upload.wikimedia.org/wikipedia/commons/5/55/Viceroy_Butterfly.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse4.mm.bing.net/th?id=OIP.QPUnAeaxqMOJbZakxrVP2QHaFu&pid=Api",
#     "title": "File:Viceroy Butterfly.jpg - Wikimedia Commons",
#     "url": "http://commons.wikimedia.org/wiki/File:Viceroy_Butterfly.jpg",
#     "width": 1027
# }
# {
#     "height": 2822,
#     "image": "http://www.syvnature.org/wp-content/uploads/2017/08/Monarch-Butterflies-MSchlinger-e1501869302858.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse2.mm.bing.net/th?id=OIP.mOw7rbtHnL9qjgO1vjvKEgHaHx&pid=Api",
#     "title": "Thursday, December 7: Monarch Butterflies - Facts and Fate",
#     "url": "https://www.syvnature.org/thursday-december-7-monarch-butterflies-facts-and-fate/",
#     "width": 2691
# }
# {
#     "height": 2304,
#     "image": "https://jooinn.com/images/beautiful-butterfly-6.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse4.mm.bing.net/th?id=OIP.3cSN4in-ZKlFS8lJhHTpSAHaE8&pid=Api",
#     "title": "Free photo: Beautiful Butterfly - Animal, Butterfly, Fly - Free ...",
#     "url": "https://jooinn.com/beautiful-butterfly-5.html",
#     "width": 3456
# }
# {
#     "height": 2304,
#     "image": "https://i.natgeofe.com/k/cec53229-3f25-4826-b842-5b754429f084/monarch-butterfly-sky_4x3.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse2.mm.bing.net/th?id=OIP.3QEUlsHir_L0Es0G5BB--gHaFj&pid=Api",
#     "title": "monarch butterfly life expectancy - Merrilee Mathias",
#     "url": "https://merrileemathias.blogspot.com/2022/11/monarch-butterfly-life-expectancy.html",
#     "width": 3072
# }
# {
#     "height": 2466,
#     "image": "http://upload.wikimedia.org/wikipedia/commons/c/cc/Blue_Morpho_Didius_Butterfly.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse3.mm.bing.net/th?id=OIP.Yi6Y6sWiwVCu1QHsMvQDXgHaEk&pid=Api",
#     "title": "File:Blue Morpho Didius Butterfly.jpg",
#     "url": "http://commons.wikimedia.org/wiki/File:Blue_Morpho_Didius_Butterfly.jpg",
#     "width": 4000
# }
# {
#     "height": 1174,
#     "image": "https://npr.brightspotcdn.com/dims4/default/e2ff6e0/2147483647/strip/true/crop/3741x2494+0+0/resize/1760x1174!/quality/90/?url=http://npr-brightspot.s3.amazonaws.com/ad/8b/eff73f8347019623aa5a3a70562e/istock-1435078652.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse4.mm.bing.net/th?id=OIP.GYfbe3hhi4zsZWpQz_gecgHaE8&pid=Api",
#     "title": "The Secret Lives of Blue Butterflies | Montana Public Radio",
#     "url": "https://www.mtpr.org/podcast/field-notes/2023-01-07/the-secret-lives-of-blue-butterflies",
#     "width": 1760
# }
# {
#     "height": 2575,
#     "image": "https://www.thespruce.com/thmb/19wfwEKpYGNak7dlxzZvIOI-Ejs=/3870x2575/filters:no_upscale():max_bytes(150000):strip_icc()/monarchbutterflybush-56cb3a725f9b5879cc542678.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse1.mm.bing.net/th?id=OIP.T4dMSyXqcBzJAwgI91Qx8gHaE7&pid=Api",
#     "title": "7 Flowers That Attract Monarch Butterflies",
#     "url": "https://www.thespruce.com/flowers-that-attract-monarch-butterflies-3882326",
#     "width": 3870
# }
# {
#     "height": 1073,
#     "image": "https://cdn.britannica.com/01/100801-050-B24D04D0/Mourning-cloak-butterfly.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse1.mm.bing.net/th?id=OIP.smMcyZveZLm3KErG5lufegHaE9&pid=Api",
#     "title": "Butterfly | Life Cycle, Classification, & Facts | Britannica",
#     "url": "https://www.britannica.com/animal/butterfly-insect",
#     "width": 1600
# }
# {
#     "height": 1000,
#     "image": "https://as2.ftcdn.net/v2/jpg/05/69/91/13/1000_F_569911359_k4X04XkmpOG9FNU2pQJlyJ8bihbAC4Uq.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse2.mm.bing.net/th?id=OIP.ukYhOGhRT2_lqXtWjDgYXAHaHa&pid=Api",
#     "title": "Beautiful blue butterfly in full body close-up portrait, flying with ...",
#     "url": "https://stock.adobe.com/images/beautiful-blue-butterfly-in-full-body-close-up-portrait-flying-with-grace-generative-ai/569911359",
#     "width": 1000
# }
# {
#     "height": 1920,
#     "image": "https://wildboyzphotography.com/wp-content/uploads/2020/05/Monarch-Butterfly-scaled.jpeg?x57213",
#     "source": "Bing",
#     "thumbnail": "https://tse1.mm.bing.net/th?id=OIP.9tdUF2GXx1QOx73AanZqQAHaFj&pid=Api",
#     "title": "June Gallery 2020",
#     "url": "https://wildboyzphotography.com/june-gallery-2020/",
#     "width": 2560
# }
# {
#     "height": 2304,
#     "image": "https://i.natgeofe.com/k/9acd2bad-fb0e-43a8-935d-ec0aefc60c2f/monarch-butterfly-grass_4x3.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse1.mm.bing.net/th?id=OIP.Hk29gdbwBCUTO9mUEs6iggHaFj&pid=Api",
#     "title": "Pictures Of Butterflies",
#     "url": "https://ar.inspiredpencil.com/pictures-2023/pictures-of-butterflies",
#     "width": 3072
# }
# {
#     "height": 1389,
#     "image": "https://i.pinimg.com/originals/a6/e1/f7/a6e1f7840f61e21b625393b66a9d2951.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse2.mm.bing.net/th?id=OIP.OLpw-WuXkQu_rDJPtnaL2wHaGB&pid=Api",
#     "title": "Habit 2 for Amazing Photographs. | Beautiful butterflies, Most ...",
#     "url": "https://www.pinterest.fr/pin/449163762810024885/",
#     "width": 1707
# }
# {
#     "height": 1067,
#     "image": "http://upload.wikimedia.org/wikipedia/commons/1/16/Ulysses_Butterfly_-_melbourne_zoo.jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse4.mm.bing.net/th?id=OIP.MP-OQXdhMBUneGfolIT8jgHaE8&pid=Api",
#     "title": "File:Ulysses Butterfly - melbourne zoo.jpg - Wikipedia, the free ...",
#     "url": "http://en.wikipedia.org/wiki/file:ulysses_butterfly_-_melbourne_zoo.jpg",
#     "width": 1600
# }
# {
#     "height": 931,
#     "image": "https://upload.wikimedia.org/wikipedia/commons/3/3d/Fesoj_-_Papilio_machaon_(by).jpg",
#     "source": "Bing",
#     "thumbnail": "https://tse3.mm.bing.net/th?id=OIP.jW8D-m7vezIrcEh7UeIrGgHaHa&pid=Api",
#     "title": "Butterfly - Wikipedia",
#     "url": "https://en.wikipedia.org/wiki/Butterfly",
#     "width": 931
# }
# {
#     "height": 1687,
#     "image": "https://www.gannett-cdn.com/presto/2020/01/23/USAT/ff2e3445-a247-456a-a551-c54fa577b522-AP_California_Monarch_Butterflies.JPG?crop=2999,1687,x0,y152&width=2999&height=1687&format=pjpg&auto=webp",
#     "source": "Bing",
#     "thumbnail": "https://tse4.mm.bing.net/th?id=OIP.TU9Au3cyrf8DpMA86mXSngHaEK&pid=Api",
#     "title": "Survey: Western monarch butterfly moving closer to extinction",
#     "url": "https://www.statesmanjournal.com/story/tech/science/environment/2021/01/19/survey-western-monarch-butterfly-moving-closer-extinction/4218184001/",
#     "width": 2999
# }
# ['http://upload.wikimedia.org/wikipedia/commons/a/ab/Monarch_Butterfly_Showy_Male_3000px.jpg', 'https://cdn.britannica.com/76/151376-050-13586FE2/monarch-butterfly-flowers-bush.jpg', 'http://upload.wikimedia.org/wikipedia/commons/7/7c/Butterfly_macro.JPG', 'http://upload.wikimedia.org/wikipedia/commons/b/b5/Monarch_Butterfly_Danaus_plexippus_on_Echinacea_purpurea_2800px.jpg', 'http://upload.wikimedia.org/wikipedia/commons/2/20/Monarch_Butterfly_resting_on_fennel,_at_the_Pismo_Butterfly_Grove,_California.jpg', 'http://upload.wikimedia.org/wikipedia/commons/5/55/Viceroy_Butterfly.jpg', 'http://www.syvnature.org/wp-content/uploads/2017/08/Monarch-Butterflies-MSchlinger-e1501869302858.jpg', 'https://jooinn.com/images/beautiful-butterfly-6.jpg', 'https://i.natgeofe.com/k/cec53229-3f25-4826-b842-5b754429f084/monarch-butterfly-sky_4x3.jpg', 'http://upload.wikimedia.org/wikipedia/commons/c/cc/Blue_Morpho_Didius_Butterfly.jpg', 'https://npr.brightspotcdn.com/dims4/default/e2ff6e0/2147483647/strip/true/crop/3741x2494+0+0/resize/1760x1174!/quality/90/?url=http://npr-brightspot.s3.amazonaws.com/ad/8b/eff73f8347019623aa5a3a70562e/istock-1435078652.jpg', 'https://www.thespruce.com/thmb/19wfwEKpYGNak7dlxzZvIOI-Ejs=/3870x2575/filters:no_upscale():max_bytes(150000):strip_icc()/monarchbutterflybush-56cb3a725f9b5879cc542678.jpg', 'https://cdn.britannica.com/01/100801-050-B24D04D0/Mourning-cloak-butterfly.jpg', 'https://as2.ftcdn.net/v2/jpg/05/69/91/13/1000_F_569911359_k4X04XkmpOG9FNU2pQJlyJ8bihbAC4Uq.jpg', 'https://wildboyzphotography.com/wp-content/uploads/2020/05/Monarch-Butterfly-scaled.jpeg?x57213', 'https://i.natgeofe.com/k/9acd2bad-fb0e-43a8-935d-ec0aefc60c2f/monarch-butterfly-grass_4x3.jpg', 'https://i.pinimg.com/originals/a6/e1/f7/a6e1f7840f61e21b625393b66a9d2951.jpg', 'http://upload.wikimedia.org/wikipedia/commons/1/16/Ulysses_Butterfly_-_melbourne_zoo.jpg', 'https://upload.wikimedia.org/wikipedia/commons/3/3d/Fesoj_-_Papilio_machaon_(by).jpg', 'https://www.gannett-cdn.com/presto/2020/01/23/USAT/ff2e3445-a247-456a-a551-c54fa577b522-AP_California_Monarch_Butterflies.JPG?crop=2999,1687,x0,y152&width=2999&height=1687&format=pjpg&auto=webp']

# %%
for count, found_image in enumerate(found_images):
    try:
        url = found_image
        urllib.request.urlretrieve(url, f"{count}.png") 
        
        # Opening the image and displaying it (to confirm its presence) 
        img = Image.open(rf"{count}.png") 
        img.show()
    except HTTPError:
        pass
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       1 for count, found_image in enumerate(found_images):
#       3     url = found_image
# ----> 4     urllib.request.urlretrieve(url, f"{count}.png")
#       6     # Opening the image and displaying it (to confirm its presence)
#       7     img = Image.open(rf"{count}.png")
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:240, in urlretrieve(url, filename, reporthook, data)
#     223 """
#     224 Retrieve a URL into a temporary location on disk.
#     225
#    (...)
#     236 data file as well as the resulting HTTPMessage object.
#     237 """
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#     243     # Just return the local path and the "headers" for file://
#     244     # URLs. No sense in performing a copy unless requested.
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 406: Not Acceptable
